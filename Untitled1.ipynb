# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
train = pd.read_csv('data_set/titanic/train.csv')

# %%
test = pd.read_csv('data_set/titanic/test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.pairplot(data = train, vars =train[['Age','Fare']])
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
encoder = OneHotEncoder(drop = 'first', sparse = False)

# %%
datas = [train,test]
for dataset in datas:
    # Fit and transform 'Sex' column
    dataset['Sex'] = encoder.fit_transform(dataset['Sex'].values.reshape(-1, 1))
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\amil\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  1.0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0      1
# 2                               Heikkinen, Miss. Laina  0.0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0      1
# 4                             Allen, Mr. William Henry  1.0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James  1.0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  0.0
# 2            894       2                     Myles, Mr. Thomas Francis  1.0
# 3            895       3                              Wirz, Mr. Albert  1.0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  0.0
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf  1.0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  0.0
# 415         1307       3                  Saether, Mr. Simon Sivertsen  1.0
# 416         1308       3                           Ware, Mr. Frederick  1.0
# 417         1309       3                      Peter, Master. Michael J  1.0
#
# ...

# %%
for dataset in datas:
    dataset['Family'] = dataset['SibSp'] + dataset['Parch'] + 1
    dataset.drop(columns = ['SibSp','Parch','Name','Cabin','PassengerId','Ticket'], inplace = True)

# %%
train
# Out:
#      Survived  Pclass  Sex   Age     Fare Embarked  Family
# 0           0       3  1.0  22.0   7.2500        S       2
# 1           1       1  0.0  38.0  71.2833        C       2
# 2           1       3  0.0  26.0   7.9250        S       1
# 3           1       1  0.0  35.0  53.1000        S       2
# 4           0       3  1.0  35.0   8.0500        S       1
# ..        ...     ...  ...   ...      ...      ...     ...
# 886         0       2  1.0  27.0  13.0000        S       1
# 887         1       1  0.0  19.0  30.0000        S       1
# 888         0       3  0.0   NaN  23.4500        S       4
# 889         1       1  1.0  26.0  30.0000        C       1
# 890         0       3  1.0  32.0   7.7500        Q       1
#
# [891 rows x 7 columns]

# %%
sns.distplot(a = train_copy['Age'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.distplot(a = train_copy['Age'])
#
# NameError: name 'train_copy' is not defined

# %%
sns.boxplot(data= train, x = 'Fare')

# %%
sns.histplot(data = train, x = 'Fare')

# %%
sns.distplot(a = train['Fare'])

# %%
train_copy = train.copy()

# %%
bins = [0,20,21,40,41,60,61,80,81,100]

# %%
# Identifying outliers using IQR method
Q1 = train_copy['Fare'].quantile(0.25)
Q3 = train_copy['Fare'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Removing outliers
train_copy = train_copy[(train_copy['Fare'] >= lower_bound) & (train_copy['Fare'] <= upper_bound)]
sns.histplot(data = train_copy, x = 'Fare')
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
train_cop['Fare'] = np.log10(train_copy['Fare'])+1

sns.histplot(train_cop['Fare'], kde=True)
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 train_cop['Fare'] = np.log10(train_copy['Fare'])+1
#       3 sns.histplot(train_cop['Fare'], kde=True)
#
# NameError: name 'train_cop' is not defined

# %%
# Identifying outliers using IQR method
Q1 = train_copy['Fare'].quantile(0.25)
Q3 = train_copy['Fare'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Removing outliers
train_copy = train_copy[(train_copy['Fare'] >= lower_bound) & (train_copy['Fare'] <= upper_bound)]

# %%
from sklearn.preprocessing import QuantileTransformer

# Assuming train_copy is your DataFrame and 'Fare' is the column to be transformed
scaler = QuantileTransformer(output_distribution='normal')
train_copy['Fare'] = scaler.fit_transform(train_copy['Fare'].values.reshape(-1, 1))

# Plotting the transformed data
sns.histplot(train_copy['Fare'], kde=True)  # Using histplot for better support with KDE
plt.xlabel('Quantile Transformed Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Quantile Transformed Fare')
plt.show()
train['Fare'] = train_copy['Fare']
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (750). n_quantiles is set to n_samples.
#   warnings.warn(
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(train['Fare'], kde=True)  # Using histplot for better support with KDE
plt.xlabel('Quantile Transformed Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Quantile Transformed Fare')
plt.show()
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
train.isna().sum()

# %%
for dataset in datas:
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = 'mean')
for dataset in datas:
    dataset[['Fare', 'Age']] = imputer.fit_transform(dataset[['Fare', 'Age']])

# %%
train.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# Age             0
# Fare            0
# Embarked        2
# Family          0
# Embarked_C    473
# Embarked_Q    473
# dtype: int64

# %%
encoder = OneHotEncoder(drop = 'first',sparse = False, dtype= int, categories=[['S', 'C', 'Q']])

# %%
datas = [test]
for dataset in datas :
    encoded = encoder.fit_transform(dataset['Embarked'].values.reshape(-1,1))
    encoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(['Embarked']))
    existing_columns = train.columns.tolist()
    new_columns = [col for col in encoded_df.columns if col not in existing_columns]
    train = pd.concat([train, encoded_df[new_columns]], axis=1)
    test = pd.concat([train, encoded_df[new_columns]], axis=1)
encoded_df
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#      Embarked_C  Embarked_Q
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           0
# 4             0           0
# ..          ...         ...
# 413           0           0
# 414           1           0
# 415           0           0
# 416           0           0
# 417           1           0
#
# [418 rows x 2 columns]

# %%
train.drop(columns=['Embarked_C', 'Embarked_Q'], inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train['Fare'] = scaler.fit_transform(train['Fare'].values.reshape(-1,1))

# %%
sns.pairplot(data = train, hue = 'Survived')
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\amil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
train
# Out:
#      Survived  Pclass  Sex        Age      Fare Embarked  Family  Embarked_C  \
# 0           0       3  1.0  22.000000  0.377559        S       2         0.0
# 1           1       1  0.0  38.000000  0.496247        C       2         0.0
# 2           1       3  0.0  26.000000  0.452065        S       1         0.0
# 3           1       1  0.0  35.000000  1.000000        S       2         0.0
# 4           0       3  1.0  35.000000  0.463240        S       1         0.0
# ..        ...     ...  ...        ...       ...      ...     ...         ...
# 886         0       2  1.0  27.000000  0.510318        S       1         NaN
# 887         1       1  0.0  19.000000  0.609463        S       1         NaN
# 888         0       3  0.0  29.699118  0.558439        S       4         NaN
# 889         1       1  1.0  26.000000  0.609463        C       1         NaN
# 890         0       3  1.0  32.000000  0.405760        Q       1         NaN
#
#      Embarked_Q
# 0           1.0
# ...

# %% [markdown]
# test

# %%
test

# %%
datas = [train,test]
for dataset in datas:
    dataset.drop(columns = 'Embarked', inplace = True)

# %%
test

# %%
sns.heatmap(data = train.corr(), annot = True)
